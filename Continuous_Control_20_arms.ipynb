# %% [markdown]
# # Continuous Control solving for 20 agents
#
# ---
#
# You are welcome to use this coding environment to train your agent for the project.  Follow the instructions below to get started!
#
# ### 1. Start the Environment
#
# Run the next code cell to install a few packages.  This line will take a few minutes to run!

# %%
#!pip -q install ./python

# %% [markdown]
# The environments corresponding to both versions of the environment are already saved in the Workspace and can be accessed at the file paths provided below.
#
# Please select one of the two options below for loading the environment.

# %%
from unityagents import UnityEnvironment
import numpy as np

# select this option to load version 1 (with a single agent) of the environment
#env = UnityEnvironment(file_name='/data/Reacher_One_Linux_NoVis/Reacher_One_Linux_NoVis.x86_64')

env = UnityEnvironment(file_name='data/Reacher_Linux/Reacher.x86_64')

# select this option to load version 2 (with 20 agents) of the environment
# env = UnityEnvironment(file_name='/data/Reacher_Linux_NoVis/Reacher.x86_64')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
import torch
torch.__version__
# on Nvidia RTX 2080Ti you need to remove the pytorch 0.4 and install the latest 1.3.1
# Out:
# '1.3.1'

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 20
# Size of each action: 4
# There are 20 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.75471878e+00 -1.00000000e+00
#   5.55726624e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Note that **in this coding environment, you will not be able to watch the agents while they are training**, and you should set `train_mode=True` to restart the environment.

# %%
env_info = env.reset(train_mode=True)[brain_name]      # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
while True:
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))

# %% [markdown]
# When finished, you can close the environment.

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  A few **important notes**:
# - When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```
# - To structure your work, you're welcome to work directly in this Jupyter notebook, or you might like to start over with a new file!  You can see the list of files in the workspace by clicking on **_Jupyter_** in the top left corner of the notebook.
# - In this coding environment, you will not be able to watch the agents while they are training.  However, **_after training the agents_**, you can download the saved model weights to watch the agents on your own machine!

# %%
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline
import torch
#from ddpg_agent import Agent
from ddpg_agent_Copy2 import Agent

#
# the ddpg_agent_Copy2 uses the model_Copy2.py, where the network is defined with 256 nodes 
#

# %%
def ddpg(n_episodes=200, max_t=1000, print_every=1):
    #scores_deque = deque(maxlen=print_every)
    #scores = []
    mean_scores = []
    scores_window = deque(maxlen=100)  # mean scores from most recent episodes
    moving_avgs = []                               # list of moving averages
    for i_episode in range(1, n_episodes+1):
        
        env_info = env.reset(train_mode=True)[brain_name]
        states = env_info.vector_observations #[0]
        scores = np.zeros(num_agents) #0
        agent.reset()
        
        for t in range(max_t):
            actions = agent.act(states)   
            env_info = env.step(actions)[brain_name]        # send the action to the environment
            next_states = env_info.vector_observations #[0]#[0]   # get the next state
            rewards = env_info.rewards #[0]#[0]                   # get the reward
            dones = env_info.local_done #[0]#[0]                  # see if episode has finished
            
            for state, action, reward, next_state, done in zip(states, actions, rewards, next_states, dones):
                agent.step(state, action, reward, next_state, done, t)
            # save experience to replay buffer, perform learning step at defined interval
            #for s, a, r, ns, d in zip(state, action, reward, next_state, done):
            #    agent.step(s, a, r, ns, d, t)
            states = next_states
            scores += rewards
            if np.any(dones):
                break 
#        scores_deque.append(scores)
#        scores.append(scores)
        #mean_scores = 
        mean_scores.append(np.mean(scores)) 
        scores_window.append(mean_scores[-1])         
        moving_avgs.append(np.mean(scores_window))
        
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, mean_scores[-1]), end="")
        if mean_scores[-1] >= 30:
            torch.save(agent.actor_local.state_dict(), '20_arms-actor.pth')
            torch.save(agent.critic_local.state_dict(), '20_arms-critic.pth')
        if i_episode % print_every == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, mean_scores[-1]))
            
        if moving_avgs[-1] >= 30 and i_episode >= 100:
            print('\nEnvironment solved in {} episodes!'.format(i_episode-100))  
            
    return mean_scores #, moving_avgs


#agent = Agent(state_size=3, action_size=1, random_seed=2)
agent = Agent(state_size=state_size, action_size=action_size, random_seed=1)



scores = ddpg()

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# /home/mond/virt_env/DRLND/lib/python3.6/site-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Episode 1	Average Score: 1.03
# Episode 2	Average Score: 1.28
# Episode 3	Average Score: 1.22
# Episode 4	Average Score: 1.40
# Episode 5	Average Score: 1.37
# Episode 6	Average Score: 1.84
# Episode 7	Average Score: 2.05
# Episode 8	Average Score: 1.84
# Episode 9	Average Score: 1.77
# Episode 10	Average Score: 2.50
# Episode 11	Average Score: 2.32
# Episode 12	Average Score: 2.54
# Episode 13	Average Score: 3.47
# Episode 14	Average Score: 3.77
# Episode 15	Average Score: 4.87
# Episode 16	Average Score: 6.02
# Episode 17	Average Score: 5.77
# Episode 18	Average Score: 7.96
#
# Environment solved in 9 episodes!
# Episode 110	Average Score: 35.67
#
# Environment solved in 10 episodes!
# Episode 111	Average Score: 37.65
#
# Environment solved in 11 episodes!
# Episode 112	Average Score: 37.53
#
# Environment solved in 12 episodes!
# Episode 113	Average Score: 38.39
#
# Environment solved in 13 episodes!
# Episode 114	Average Score: 37.75
#
# Environment solved in 14 episodes!
# Episode 115	Average Score: 36.82
#
# Environment solved in 15 episodes!
# Episode 116	Average Score: 37.12
#
# Environment solved in 16 episodes!
# Episode 117	Average Score: 37.97
#
# Environment solved in 17 episodes!
# Episode 118	Average Score: 37.83
#
# Environment solved in 18 episodes!
# Episode 119	Average Score: 36.44
#
# Environment solved in 19 episodes!
# Episode 120	Average Score: 37.58
#
# Environment solved in 20 episodes!
# Episode 121	Average Score: 37.82
#
# Environment solved in 21 episodes!
# Episode 122	Average Score: 36.22
#
# Environment solved in 22 episodes!
# Episode 123	Average Score: 35.93
#
# Environment solved in 23 episodes!
# Episode 124	Average Score: 21.31
#
# Environment solved in 24 episodes!
# Episode 125	Average Score: 9.09
#
# Environment solved in 25 episodes!
# Episode 126	Average Score: 20.42
#
# Environment solved in 26 episodes!
# Episode 127	Average Score: 30.65
#
# Environment solved in 27 episodes!
# Episode 128	Average Score: 37.16
#
# Environment solved in 28 episodes!
# Episode 129	Average Score: 36.01
#
# Environment solved in 29 episodes!
# Episode 130	Average Score: 34.55
#
# Environment solved in 30 episodes!
# Episode 131	Average Score: 33.65
#
# Environment solved in 31 episodes!
# Episode 132	Average Score: 38.23
#
# Environment solved in 32 episodes!
# Episode 133	Average Score: 37.42
#
# Environment solved in 33 episodes!
# Episode 134	Average Score: 38.54
#
# Environment solved in 34 episodes!
# Episode 135	Average Score: 37.05
#
# Environment solved in 35 episodes!
# Episode 136	Average Score: 38.04
#
# Environment solved in 36 episodes!
# Episode 137	Average Score: 38.17
#
# Environment solved in 37 episodes!
# Episode 138	Average Score: 37.90
#
# Environment solved in 38 episodes!
# Episode 139	Average Score: 38.17
#
# Environment solved in 39 episodes!
# Episode 140	Average Score: 38.83
#
# Environment solved in 40 episodes!
# Episode 141	Average Score: 37.85
#
# Environment solved in 41 episodes!
# Episode 142	Average Score: 37.75
#
# Environment solved in 42 episodes!
# Episode 143	Average Score: 37.28
#
# Environment solved in 43 episodes!
# Episode 144	Average Score: 37.69
#
# Environment solved in 44 episodes!
# Episode 145	Average Score: 38.06
#
# Environment solved in 45 episodes!
# Episode 146	Average Score: 37.60
#
# Environment solved in 46 episodes!
# Episode 147	Average Score: 36.20
#
# Environment solved in 47 episodes!
# Episode 148	Average Score: 34.10
#
# Environment solved in 48 episodes!
# Episode 149	Average Score: 30.55
#
# Environment solved in 49 episodes!
# Episode 150	Average Score: 29.73
#
# Environment solved in 50 episodes!
# Episode 151	Average Score: 32.34
#
# Environment solved in 51 episodes!
# Episode 152	Average Score: 37.87
#
# Environment solved in 52 episodes!
# Episode 153	Average Score: 38.20
#
# Environment solved in 53 episodes!
# Episode 154	Average Score: 38.33
#
# Environment solved in 54 episodes!
# Episode 155	Average Score: 36.91
#
# Environment solved in 55 episodes!
# Episode 156	Average Score: 37.41
#
# Environment solved in 56 episodes!
# Episode 157	Average Score: 37.54
#
# Environment solved in 57 episodes!
# Episode 158	Average Score: 35.69
#
# Environment solved in 58 episodes!
# Episode 159	Average Score: 33.50
#
# Environment solved in 59 episodes!
# Episode 160	Average Score: 37.26
#
# Environment solved in 60 episodes!
# Episode 161	Average Score: 34.71
#
# Environment solved in 61 episodes!
# Episode 162	Average Score: 37.34
#
# Environment solved in 62 episodes!
# Episode 163	Average Score: 35.80
#
# Environment solved in 63 episodes!
# Episode 164	Average Score: 29.94
#
# Environment solved in 64 episodes!
# Episode 165	Average Score: 28.35
#
# Environment solved in 65 episodes!
# Episode 166	Average Score: 27.70
#
# Environment solved in 66 episodes!
# Episode 167	Average Score: 19.75
#
# Environment solved in 67 episodes!
# Episode 168	Average Score: 23.40
#
# Environment solved in 68 episodes!
# Episode 169	Average Score: 19.89
#
# Environment solved in 69 episodes!
# Episode 170	Average Score: 25.43
#
# Environment solved in 70 episodes!
# Episode 171	Average Score: 22.34
#
# Environment solved in 71 episodes!
# Episode 172	Average Score: 27.79
#
# Environment solved in 72 episodes!
# Episode 173	Average Score: 32.46
#
# Environment solved in 73 episodes!
# Episode 174	Average Score: 35.67
#
# Environment solved in 74 episodes!
# Episode 175	Average Score: 37.41
#
# Environment solved in 75 episodes!
# Episode 176	Average Score: 37.89
#
# Environment solved in 76 episodes!
# Episode 177	Average Score: 35.71
#
# Environment solved in 77 episodes!
# Episode 178	Average Score: 37.29
#
# Environment solved in 78 episodes!
# Episode 179	Average Score: 37.62
#
# Environment solved in 79 episodes!
# Episode 180	Average Score: 37.85
#
# Environment solved in 80 episodes!
# Episode 181	Average Score: 38.13
#
# Environment solved in 81 episodes!
# Episode 182	Average Score: 36.04
#
# Environment solved in 82 episodes!
# Episode 183	Average Score: 37.34
#
# Environment solved in 83 episodes!
# Episode 184	Average Score: 38.80
#
# Environment solved in 84 episodes!
# Episode 185	Average Score: 37.96
#
# Environment solved in 85 episodes!
# Episode 186	Average Score: 34.96
#
# Environment solved in 86 episodes!
# Episode 187	Average Score: 31.90
#
# Environment solved in 87 episodes!
# Episode 188	Average Score: 37.79
#
# Environment solved in 88 episodes!
# Episode 189	Average Score: 37.37
#
# Environment solved in 89 episodes!
# Episode 190	Average Score: 35.12
#
# Environment solved in 90 episodes!
# Episode 191	Average Score: 33.32
#
# Environment solved in 91 episodes!
# Episode 192	Average Score: 34.03
#
# Environment solved in 92 episodes!
# Episode 193	Average Score: 32.50
#
# Environment solved in 93 episodes!
# Episode 194	Average Score: 30.04
#
# Environment solved in 94 episodes!
# Episode 195	Average Score: 30.92
#
# Environment solved in 95 episodes!
# Episode 196	Average Score: 32.62
#
# Environment solved in 96 episodes!
# Episode 197	Average Score: 36.50
#
# Environment solved in 97 episodes!
# Episode 198	Average Score: 36.34
#
# Environment solved in 98 episodes!
# Episode 199	Average Score: 35.97
#
# Environment solved in 99 episodes!
# Episode 200	Average Score: 37.21
#
# Environment solved in 100 episodes!

# %%
env.close()
